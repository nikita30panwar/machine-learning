# %% [markdown]
# <a href="https://colab.research.google.com/github/nikita30panwar/machine-learning/blob/main/Assignments/Nikita_Panwar_801372070_Assingment_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd

# %%
# !git clone https://github.com/nikita30panwar/machine-learning.git
# Out:
# Cloning into 'machine-learning'...
# remote: Enumerating objects: 25, done.
# remote: Counting objects: 100% (25/25), done.
# remote: Compressing objects: 100% (20/20), done.
# remote: Total 25 (delta 0), reused 0 (delta 0), pack-reused 0
# Receiving objects: 100% (25/25), 14.85 KiB | 14.85 MiB/s, done.

# %%
data = pd.read_csv('machine-learning/Data/D3.csv',na_values='*')
display(data)
# Out:
#           X1        X2        X3         Y
# 0   0.000000  3.440000  0.440000  4.387545
# 1   0.040404  0.134949  0.888485  2.679650
# 2   0.080808  0.829899  1.336970  2.968490
# 3   0.121212  1.524848  1.785455  3.254065
# 4   0.161616  2.219798  2.233939  3.536375
# ..       ...       ...       ...       ...
# 95  3.838384  1.460202  3.046061 -4.440595
# 96  3.878788  2.155152  3.494545 -4.458663
# 97  3.919192  2.850101  3.943030 -4.479995
# 98  3.959596  3.545051  0.391515 -3.304593
# 99  4.000000  0.240000  0.840000 -5.332455
#
# [100 rows x 4 columns]
